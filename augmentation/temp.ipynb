# %%
from matplotlib import pyplot as plt
import math
import os
import numpy as np
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
import nibabel as nib
from utils.model.generate_image import generate_image
from monai.transforms import RandRotate
import monai.transforms as transforms
import torch
import torch.nn as nn
import torch.optim as optim
from monai.transforms import RandFlip
#%matplotlib inline
from visualization.display_image import display_image

image = nib.load('test_data/image.nii.gz')
mask = nib.load('test_data/mask.nii.gz')
concat = nib.load('test_data/concat.nii.gz')

image_affine = image.affine
mask_affine = mask.affine
concat_affine = concat.affine

image_data = image.get_fdata()
mask_data = mask.get_fdata()
concat_data = concat.get_fdata()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 7
#       5 os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
#       6 import nibabel as nib
# ----> 7 from utils.model.generate_image import generate_image
#       8 from monai.transforms import RandRotate
#       9 import monai.transforms as transforms
#
# File ~\Desktop\Master\code\utils\model\generate_image.py:1
# ----> 1 import torch
#       2 from model.get_model import get_model
#       3 from model.utils import trim_state_dict_name
#
# File ~\miniconda3\lib\site-packages\torch\__init__.py:128
#     126     err = ctypes.WinError(last_error)
#     127     err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 128     raise err
#     129 elif res is not None:
#     130     is_loaded = True
#
# ...

# %%
display_image(image_data, colormap='gray', n_slices=10)

# %%
augmented = transforms.Rotate(angle=30, keep_size=True, mode='bilinear', align_corners=True)

display_image(augmented(image_data), colormap='gray', n_slices=10)
